# %% [markdown]
# <a href="https://colab.research.google.com/github/jarwarayaz/GOOGLE_COLAB/blob/main/Display_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
print("ORIGINAL IMAGE")
image=cv2.imread('/Ayaz.jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(image)
image1=cv2.imread('/Ayaz.jpg',0)
cv2_imshow(image1)
cv2.imwrite('AyazGray.png',image1)
# Out:
# ORIGINAL IMAGE
# <PIL.Image.Image image mode=RGB size=640x640>
# <PIL.Image.Image image mode=L size=640x640>
# True
