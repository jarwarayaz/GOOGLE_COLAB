# %% [markdown]
# <a href="https://colab.research.google.com/github/jarwarayaz/GOOGLE_COLAB/blob/main/Image_to_Array.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
image=cv2.imread('/content/Ayaz.jpg')
from google.colab.patches import cv2_imshow
cv2_imshow(image)
from numpy import asarray
data= asarray(image)
print(data)
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>
# [[[243 245 246]
#   [243 245 246]
#   [243 245 246]
#   ...
#   [200 205 196]
#   [199 204 195]
#   [199 204 195]]
#
#  [[243 245 246]
#   [243 245 246]
#   [243 245 246]
#   ...
#   [200 205 196]
#   [199 204 195]
#   [199 204 195]]
#
#  [[243 245 246]
#   [243 245 246]
#   [243 245 246]
#   ...
#   [200 205 196]
#   [200 205 196]
#   [200 205 196]]
#
#  ...
#
#  [[178 187 221]
#   [178 187 221]
#   [180 189 223]
#   ...
#   [ 63  73 113]
#   [ 75  85 125]
#   [ 82  92 132]]
#
#  [[176 185 219]
#   [175 184 218]
#   [176 185 219]
#   ...
#   [ 62  72 112]
#   [ 74  84 124]
#   [ 83  93 133]]
#
#  [[174 183 217]
#   [171 180 214]
#   [173 182 216]
#   ...
#   [ 58  68 108]
#   [ 70  80 120]
#   [ 78  88 128]]]
